# %%
#Classwork 1
#Print your name and Course name
print("Name: Abdulazeez Abdulakeem")
print("Course Name: Python Beginners Class")
# Out:
# Name: Abdulazeez Abdulakeem
# Course Name: Python Beginners Class
