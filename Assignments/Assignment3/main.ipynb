# %%
from model import Fibonacci

num = 500
Math = Fibonacci(num, 2)

# %%
print(f"Fibonacci of {num}: {Math.fibonacci_of_num(num)}")

# %%
print(f"Fibonacci Series Generator (yield): {list(Math.fibonacci_series_generator_yi())}")

# %%
print(f"Fibonacci Series Generator (List):{Math.fibonacci_series_generator_ls()}")
